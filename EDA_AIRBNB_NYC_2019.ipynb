# %% [markdown]
# <a href="https://colab.research.google.com/github/Jit562/EDA_AIRBNB_NYC_2019_Data_Analysis/blob/main/EDA_AIRBNB_NYC_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name -** AIRBNB NYC 2019 Room service Data Analysis

# %% [markdown]
# *   Project Type-EDA
# *   Contribution - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The "Airbnb NYC 2019 Data Analysis" project delves into a comprehensive exploration of the Airbnb dataset focusing on New York City listings throughout the year 2019. This dataset encapsulates a wealth of information encompassing various facets of Airbnb listings, including pricing dynamics, property attributes, geographical distribution, host demographics, and guest reviews. Through meticulous analysis, the project aims to unveil valuable insights into the Airbnb market landscape, facilitating a deeper understanding of the factors influencing listing prices, occupancy rates, and customer satisfaction.
#
# Beginning with data acquisition, the project sources the Airbnb NYC 2019 dataset from reliable repositories or web scraping methodologies. Following this, a rigorous data preprocessing phase ensues, comprising tasks such as data cleaning, handling missing values, and feature engineering. This critical step ensures the dataset's integrity and sets the foundation for subsequent analyses.
#
# The project then transitions into exploratory data analysis (EDA), employing statistical techniques and data visualization tools to uncover patterns, trends, and correlations within the dataset. EDA facilitates the identification of key variables and their interrelationships, providing valuable context for subsequent analytical endeavors.
#
# Subsequently, descriptive statistics are computed to quantify central tendencies, dispersion, and distributions of pertinent variables. This quantitative analysis offers a comprehensive overview of the dataset's characteristics, laying the groundwork for further investigation.
#
# Feature importance analysis is conducted to discern the most influential factors affecting Airbnb listing prices and other relevant metrics. By employing advanced analytical techniques, the project elucidates the underlying drivers of pricing dynamics, aiding hosts and guests in making informed decisions.
#
# Model building forms a pivotal component of the project, wherein predictive models are developed to forecast listing prices or predict occupancy rates. Leveraging machine learning algorithms such as linear regression, decision trees, or ensemble methods, the project endeavors to construct robust models capable of capturing the intricacies of the Airbnb market.
#
# Model evaluation metrics are utilized to assess the predictive performance of the models, ensuring their efficacy and generalizability to real-world scenarios. Rigorous validation procedures ascertain the models' reliability and enable the derivation of actionable insights.
#
# The project culminates in the interpretation and dissemination of findings, wherein insights gleaned from the analysis are synthesized into actionable recommendations. Through compelling visualizations and comprehensive reports, stakeholders gain invaluable insights into the Airbnb market dynamics, empowering them to optimize listing strategies, enhance guest experiences, and capitalize on emerging opportunities.
#
# In essence, the "Airbnb NYC 2019 Data Analysis" project serves as a beacon of data-driven decision-making, shedding light on the intricacies of the Airbnb ecosystem and illuminating pathways to success within the vibrant landscape of short-term rentals in New York City.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Github Link: https://github.com/Jit562/EDA_AIRBNB_NYC_2019_Data_Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The primary objective of this project is to leverage data-driven insights to address key challenges encountered by hosts and guests in the New York City Airbnb market. Specifically, the project aims to:
#
# 1. Understand Pricing Dynamics: Analyze factors influencing Airbnb listing prices, such as property attributes, location, seasonality, and host characteristics. By uncovering pricing patterns and trends, hosts can optimize their pricing strategies to maximize revenue while remaining competitive in the market.
#
# 2. Enhance Listing Performance: Identify features and amenities that correlate with higher occupancy rates, positive guest reviews, and overall customer satisfaction. Insights gained from this analysis can empower hosts to enhance their listings, cater to guest preferences, and differentiate themselves in a crowded marketplace.
#
# 3. Optimize Guest Experience: Explore guest sentiments and preferences through review analysis, identifying areas for improvement and opportunities to enhance the overall guest experience. By addressing pain points and exceeding guest expectations, hosts can cultivate positive reputations and drive repeat bookings.
#
# 4. Mitigate Regulatory Risks: Assess the regulatory landscape governing short-term rentals in New York City, including compliance with local laws and regulations. Understanding regulatory requirements is essential for hosts to operate within legal boundaries and mitigate risks associated with non-compliance.

# %% [markdown]
# Define Your Business Objective?

# %% [markdown]
# By addressing these challenges, the project endeavors to empower both hosts and guests in the New York City Airbnb market, fostering a more transparent, efficient, and mutually beneficial ecosystem. Through actionable insights and strategic recommendations, stakeholders can navigate the complexities of the Airbnb marketplace with confidence, optimizing their experiences and unlocking the full potential of short-term rentals in the city that never sleeps

# %% [markdown]
# # **General Guidelines : -**

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
# The additional credits will have advantages over other students during Star Student selection.
# [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go without a single error logged. ]
# 3. Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.

# %% [markdown]
# #   Chart visualization code
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# *   Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.
# 5.  You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis ]

# %% [markdown]
# # **Let's Begin !**

# %% [markdown]
# # **1. Know Your Data**

# %% [markdown]
# # Import Libraries

# %%
# Import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime,date

# %% [markdown]
# # Dataset Loading

# %%
# Load Dataset

# %%
df = pd.read_csv('drive/MyDrive/Dataset/Copy of Airbnb NYC 2019.csv')

# %% [markdown]
# # Dataset First View

# %%
 #Dataset First Look

# %%
# Find the First 5 rows and all columns data
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Find the last 5 rows and all columns data
df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
# Find the any 5 rows and all columns data
df.sample(10)
# Out:
#              id                                               name    host_id  \
# 1819     813793   Large, Private 2-BR Flat in the Lower East Side!    4276374
# 44164  34084341     Boutique 4 Bedroom/2 Bath Home by Central Park    5325719
# 16154  13044964    Stylish and cute girly shared room in Manhattan    5288991
# 17656  13880742                               Center of the Action   30498797
# 43688  33804214        Studio sized room in Midtown-East Manhattan  136122177
# 24126  19438695                              Loft in big apartment  136285709
# 25415  20325986                    Brooklyn Condominium - Bushwick  145013050
# 47916  35985735         One Bedroom Oasis in the Heart of Brooklyn   70538107
# 44328  34177796  Blocks to the High Line * West Village Home fo...   63393553
# 31948  24938183                   Private rooftop Penthouse heaven   13089912
#
#        host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# ...

# %% [markdown]
# # Dataset Rows & Columns count

# %%
# Row And Columns
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# # Dataset Information

# %%
 #Dataset Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# # Duplicate Values

# %%
# Dataset Duplicate Value Count

# %%
df.duplicated().sum()
# Out:
# 0

# %%
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# # Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(12, 8))
sns.heatmap(df.isnull(), cmap='viridis', cbar=False, yticklabels=False)

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

plt.title('Missing Values Heatmap')
plt.show()

# %%
dff = df.drop(['last_review','reviews_per_month'],  axis=1)

# %% [markdown]
# * Drop the columns last_reviews and reviews_per_month Because this is not required. all ready review columns are available

# %%
# Visualizing the missing values after remove the columns
plt.figure(figsize=(12, 4))
sns.heatmap(dff.isnull(), cmap='viridis', cbar=False, yticklabels=False)

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')


plt.title('Missing Values Heatmap')
plt.show()

# %%
# after remove the columns are 14
dff.shape
# Out:
# (48895, 14)

# %%
dff.duplicated().sum()
# Out:
# 0

# %%
# Drop the Null values
name = dff.loc[~dff['name'].isna(),'name']

# %%
name.isnull().sum()
# Out:
# 0

# %%
# drop the null values
host_name = dff.loc[~dff['host_name'].isna(),'host_name']

# %%
host_name.isnull().sum()
# Out:
# 0

# %%
def removeprc(string): #removes the & from a string
    string = str(string)
    list = string.split('&')
    string = " ".join(list)
    return string

# %%
dff['room_type'] = dff['room_type'].apply(removeprc)

# %% [markdown]
# # What did you know about your dataset?

# %% [markdown]
# * The dataset given is a dataset from Hotel industry, and we have to analysis the Airbnb ync 2019 of customers and the insights behind it.
#
# * Airbnb ync 2019 prediction is analytical studies on the possibility of a customer abandoning a product or service. The goal is to understand and take steps to change it before the costumer gives up the product or service.
#
# * The above dataset has 48895 rows and 14 columns. There are no mising values and duplicate values in the dataset.

# %% [markdown]
# # **2. Understanding Your Variables**

# %%
# Dataset Columns
dff.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
dff.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %%
dff.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  calculated_host_listings_count  \
# count    48895.000000       48895.000000                    48895.000000
# mean         7.029962          23.274466                        7.143982
# ...

# %% [markdown]
# # Variables Description

# %% [markdown]
# Variables Description
# Index_count : Total number of Airbnb ync 2019 data 48895 and 14 columns
#
# host_id_Mean_or_AVG :6.70
#
# price_Mean_or_AVG :153
#
# Night_Mean_or_AVG : 7
#
# N_Review_Mean_or_AVG : 23
#
# Availablity_Mean_or_AVG : 112
#
# Host_listing_count_Mean_or_AVG : 7
#
# host_id_STD :7.8
#
# price_STD :240
#
# Night_Std :20
#
# N_Review_STD : 44
#
# Availablity_STD : 32
#
# Host_listing_count_STD : 131
#
# host_id_Min :2.4
#
# price_Min :0
#
# Night_Min : 1
#
# N_Review_Min : 0
#
# Availablity_Min : 0
#
# Host_listing_count_Min : 1
#
# host_id_Max :2.4
#
# price_Max :100000
#
# Night_Max : 1250
#
# N_Review_Max : 629
#
# Availablity_Max : 365
#
# Host_listing_count_Max :327
#
# host_id_25% :7.8
#
# price_25% :69
#
# Night_25% : 1
#
# N_Review_25% : 1
#
# Availablity_25% : 1
#
# Host_listing_count_25% : 0
#
# host_id_50% :3.07
#
# price_50% :106
#
# Night_50% : 3
#
# N_Review_50% : 5
#
# Availablity_50% : 45
#
# Host_listing_50% : 1
#
# host_id_75% :1.07
#
# price_75% :175
#
# Night_75% : 5
#
# N_Review_75% : 24
#
# Availablity_75% : 227
#
# Host_listing_count_75% : 2

# %% [markdown]
# # Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
dff.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
# Check Number of Unique Values for each variable using for loop.
for column in dff.columns:
    unique_values = dff[column].nunique()
    print(f"Unique values for variable '{column}' :   {unique_values}")
# Out:
# Unique values for variable 'id' :   48895
# Unique values for variable 'name' :   47905
# Unique values for variable 'host_id' :   37457
# Unique values for variable 'host_name' :   11452
# Unique values for variable 'neighbourhood_group' :   5
# Unique values for variable 'neighbourhood' :   221
# Unique values for variable 'latitude' :   19048
# Unique values for variable 'longitude' :   14718
# Unique values for variable 'room_type' :   3
# Unique values for variable 'price' :   674
# Unique values for variable 'minimum_nights' :   109
# Unique values for variable 'number_of_reviews' :   394
# Unique values for variable 'calculated_host_listings_count' :   47
# Unique values for variable 'availability_365' :   366

# %% [markdown]
# ## **Check Unique Values for each variable Summary.**

# %% [markdown]
# * Unique values for variable     'id'                                 :  48895
# * Unique values for variable     'name'                               : 47905
# * Unique values for variable     'host_id'                            : 37457
# * Unique values for variable     'host_name'                          : 11452
# * Unique values for variable     'neighbourhood_group'                : 5
# * Unique values for variable     'neighbourhood'                      : 221
# * Unique values for variable     'latitude'                           : 19048
# * Unique values for variable     'longitude'                          : 14718
# * Unique values for variable     'room_type'                          : 3
# * Unique values for variable     'price'                              : 674
# * Unique values for variable     'minimum_nights'                     : 109
# * Unique values for variable     'number_of_reviews'                  : 394
# * Unique values for variable     'calculated_host_listings_count'     : 47
# * Unique values for variable     'availability_365'                   : 366

# %% [markdown]
# # **3. Data Wrangling**

# %% [markdown]
# # Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
dff.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# ...

# %%
# Total number State wise data
dff['neighbourhood_group'].value_counts() # Univariant analysis
# Out:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: count, dtype: int64

# %% [markdown]
# # **Total number State wise data**
#
# 1. Manhattan        21661
# 2. Brooklyn         20104
# 3. Queens            5666
# 4. Bronx             1091
# 5. Staten Island      373

# %%
# Total number of city wise data
dff['neighbourhood'].value_counts() # Univariant analysis
# Out:
# neighbourhood
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
#                       ...
# Fort Wadsworth           1
# Richmondtown             1
# New Dorp                 1
# Rossville                1
# Willowbrook              1
# Name: count, Length: 221, dtype: int64

# %% [markdown]
# #Total number of city wise data

# %%
# Total number of city in the state ( Bie-Variant Analysis)
df1 = dff.sort_values(["neighbourhood_group"], ascending=True).groupby(["neighbourhood_group"])['neighbourhood'].agg(['count'])

# %% [markdown]
# # **Total number of city in the state ( Bie-Variant Analysis)**
#
# 1. Bronx	1091
# 2. Brooklyn	20104
# 3. Manhattan	21661
# 4. Queens	5666
# 5. Staten Island	373

# %%
df1
# Out:
#                      count
# neighbourhood_group
# Bronx                 1091
# Brooklyn             20104
# Manhattan            21661
# Queens                5666
# Staten Island          373

# %%
# Find the room type Quintity
dff['room_type'].value_counts().sort_values(ascending=False) # Univariant Ananlysis
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %% [markdown]
# # **Room Type**
#
# 1. Entire home room : 25409
#
# 2. Private room     : 22326
#
# 3. shared room      : 1160

# %%
# Find the Private room type Price
private_room_prices = dff[dff['room_type'] == 'Private room']['price'] # Bie Variant Analysis

# %%
#Private room type Price of mean values is 89.78
private_room_prices.mean()
# Out:
# 89.78097285675894

# %% [markdown]
# * Find the Private room type average price 89

# %%
#Private room type Price of minimun values is 0
private_room_prices.min()
# Out:
# 0

# %% [markdown]
# * Private room type Price of minimun values is 0

# %%
#11 rooms Price are 0
private_room_min_price = dff[dff['price']==0]

# %%
##11 rooms Price are 0
private_room_min_price['price'].value_counts()
# Out:
# price
# 0    11
# Name: count, dtype: int64

# %%
# Find name of State and City which rooms type price is 0
zero_price_rows = dff[dff['price'] == 0][['host_id','neighbourhood_group','neighbourhood','room_type']]
zero_price_rows
# Out:
#          host_id neighbourhood_group       neighbourhood        room_type
# 23161    8993084            Brooklyn  Bedford-Stuyvesant     Private room
# 25433  131697576               Bronx     East Morrisania     Private room
# 25634   15787004            Brooklyn            Bushwick     Private room
# 25753    1641537            Brooklyn          Greenpoint     Private room
# 25778   10132166            Brooklyn        Williamsburg  Entire home/apt
# 25794   86327101            Brooklyn  Bedford-Stuyvesant     Private room
# 25795   86327101            Brooklyn  Bedford-Stuyvesant     Private room
# 25796   86327101            Brooklyn  Bedford-Stuyvesant     Private room
# 26259   13709292           Manhattan         Murray Hill  Entire home/apt
# 26841  101970559            Brooklyn            Bushwick      Shared room
# 26866  101970559            Brooklyn            Bushwick      Shared room

# %% [markdown]
# * Find name of State and City which rooms type price is 0
#
# ![image.png](data:image/png;base64,...)

# %%
total_zero_price = zero_price_rows.shape[0]
total_zero_price
# Out:
# 11

# %%
#which rooms type Price of 0
min_room_price = dff[dff['price']==0]['room_type']

# %%
min_room_price.value_counts()
# Out:
# room_type
# Private room       7
# Entire home/apt    2
# Shared room        2
# Name: count, dtype: int64

# %% [markdown]
# # **which types of room Price 0**
#
# * there are 11 rooms price is 0
#
# 1. Private room      :    7
#
# 2. Entire home/apt   :  2
#
# 3. Shared room       :  2

# %%
#maximun rooms Price are 10000
private_room_prices.max()
# Out:
# 10000

# %% [markdown]
# * maximun rooms Price are 10000

# %%
max_room_price = dff[dff['price']==10000]['room_type'] # Bie-Variant Ananlysis

# %%
# There are 3 rooms price are 10k One Private room and Two Entire Home room
max_room_price.value_counts()
# Out:
# room_type
# Entire home/apt    2
# Private room       1
# Name: count, dtype: int64

# %% [markdown]
# # **which types of room Price 10000**
#
# * There are 3 rooms price are 10k One Private room and Two Entire Home room
#
# 1. Entire home/apt   :    2
#
# 2. Private room      :    1

# %%
maxim_room_price = dff[dff['price']==10000][['host_id','neighbourhood_group','neighbourhood','room_type']]
maxim_room_price
# Out:
#         host_id neighbourhood_group    neighbourhood        room_type
# 9151   20582832              Queens          Astoria     Private room
# 17692   5143901            Brooklyn       Greenpoint  Entire home/apt
# 29238  72390391           Manhattan  Upper West Side  Entire home/apt

# %% [markdown]
# # Maximum rooms type of price 10k which room type price 10k & which state and city in the available
#
# ![image.png](data:image/png;base64,...)

# %%
# Find the median room price
median_price = dff[dff['price'] != 0]['price'].median() # Univariant Ananlysis
median_price
# Out:
# 106.0

# %% [markdown]
# * median room price 106

# %%
# Update room price through median
dff.loc[dff['price'] == 0, 'price'] = median_price # Univariant Ananlysis

# %%
dff[dff['price']==10]['room_type'].value_counts() # Bie- Variant Ananlysis
# Out:
# room_type
# Private room       8
# Entire home/apt    7
# Shared room        2
# Name: count, dtype: int64

# %%
# which type of room number of review find
dff.groupby(['room_type']).agg({'number_of_reviews':'mean'}).round(2) # Bie Variant Ananlysis
# Out:
#                  number_of_reviews
# room_type
# Entire home/apt              22.84
# Private room                 24.11
# Shared room                  16.60

# %% [markdown]
# # find the average Reviews  of rooms type
#
# 1. Entire home/apt	22.84
# 2. Private room	24.11
# 3. Shared room	16.60

# %%
# find the room availability in days which type of room available
dff.groupby(['room_type','availability_365'])['price'].count() # Multi-Variant Ananlysis
# Out:
# room_type        availability_365
# Entire home/apt  0                   8876
#                  1                    246
#                  2                    170
#                  3                    200
#                  4                    161
#                                      ...
# Shared room      361                    8
#                  362                   13
#                  363                   16
#                  364                   15
#                  365                  129
# Name: price, Length: 965, dtype: int64

# %%
# find the minimum night stay in private room
private_room_min_nights = dff[dff['room_type'] == 'Private room']['minimum_nights'].value_counts() # Bie-Variant Ananysis
private_room_min_nights
# Out:
# minimum_nights
# 1     7887
# 2     5267
# 3     3186
# 5     1172
# 4     1144
#       ...
# 59       1
# 75       1
# 44       1
# 47       1
# 85       1
# Name: count, Length: 72, dtype: int64

# %%
# find the minimum night stay in shared room
shared_room_min_nights = dff[dff['room_type'] == 'Shared room']['minimum_nights'].value_counts() # Bie-varient Ananlysis
shared_room_min_nights
# Out:
# minimum_nights
# 1      606
# 2      193
# 30      90
# 3       85
# 5       39
# 4       37
# 7       28
# 14      24
# 10      14
# 15      10
# 100      6
# 6        4
# 31       4
# 18       2
# 60       2
# 20       2
# 9        2
# 8        1
# 11       1
# 22       1
# 12       1
# 62       1
# 26       1
# 999      1
# 120      1
# 35       1
# 27       1
# 25       1
# 90       1
# Name: count, dtype: int64

# %%
# find the minimum night stay in Entire room
Entire_home_room_min_nights = dff[dff['room_type'] == 'Entire home/apt']['minimum_nights'].value_counts()
Entire_home_room_min_nights
# Out:
# minimum_nights
# 2      6236
# 3      4728
# 1      4227
# 30     2651
# 4      2122
#        ...
# 53        1
# 55        1
# 160       1
# 999       1
# 33        1
# Name: count, Length: 91, dtype: int64

# %%
dff['calculated_host_listings_count'].value_counts() # Univariant ananlysis
# Out:
# calculated_host_listings_count
# 1      32303
# 2       6658
# 3       2853
# 4       1440
# 5        845
# 6        570
# 8        416
# 7        399
# 327      327
# 9        234
# 232      232
# 10       210
# 96       192
# 12       180
# 13       130
# 121      121
# 11       110
# 52       104
# 103      103
# 33        99
# 49        98
# 91        91
# 87        87
# 15        75
# 14        70
# 23        69
# 34        68
# 17        68
# 65        65
# 31        62
# 28        56
# 18        54
# 25        50
# 50        50
# 47        47
# 43        43
# 20        40
# 39        39
# 37        37
# 32        32
# 30        30
# 29        29
# 27        27
# 26        26
# 21        21
# 19        19
# 16        16
# Name: count, dtype: int64

# %%
# Multi Variant Ananlysis
dff.groupby(['host_name','neighbourhood_group','neighbourhood','room_type','price']).agg({'number_of_reviews':'mean'}).round(2)
# Out:
#                                                                                         number_of_reviews
# host_name                neighbourhood_group neighbourhood       room_type       price
# 'Cil                     Queens              Astoria             Private room    120                240.0
# (Ari) HENRY LEE          Manhattan           East Harlem         Entire home/apt 140                  3.0
# (Email hidden by Airbnb) Brooklyn            Clinton Hill        Entire home/apt 261                  5.0
#                                              Williamsburg        Entire home/apt 120                  0.0
#                          Manhattan           Midtown             Private room    139                  3.0
# ...                                                                                                   ...
# 빈나                       Manhattan           Stuyvesant Town     Private room    125                  1.0
# ...

# %%
#Multi-Variant Ananlysis
dff.groupby(['name','host_name','neighbourhood_group','neighbourhood','room_type','price']).agg({'number_of_reviews':'mean'}).round(2)
# Out:
#                                                                                                                          number_of_reviews
# name                                             host_name neighbourhood_group neighbourhood      room_type       price
#  1 Bed Apt in Utopic Williamsburg                Anthony   Brooklyn            Williamsburg       Entire home/apt 155                  8.0
#  2-3 bedroom UWS garden triplex                  Amy       Manhattan           Upper West Side    Entire home/apt 300                  4.0
#  3 bedroom loft in Williamsburg                  Randall   Brooklyn            Williamsburg       Entire home/apt 500                 48.0
#  A charming Space in Brooklyn                    Christine Brooklyn            Bedford-Stuyvesant Private room    95                  44.0
#  AMAZING TIME SQUARE!!BRICK WALLS!!              Mike      Manhattan           Hell's Kitchen     Entire home/apt 115                  3.0
# ...

# %%
# state by room type reviews
dff.groupby(['neighbourhood_group','room_type']).agg({'number_of_reviews':'mean'}).round(2) # Multi Variant analysis
# Out:
#                                      number_of_reviews
# neighbourhood_group room_type
# Bronx               Entire home/apt              30.68
#                     Private room                 25.02
#                     Shared room                   7.20
# Brooklyn            Entire home/apt              27.95
#                     Private room                 21.09
#                     Shared room                  14.03
# Manhattan           Entire home/apt              17.82
#                     Private room                 26.20
#                     Shared room                  21.40
# Queens              Entire home/apt              28.93
#                     Private room                 27.75
#                     Shared room                  13.86
# Staten Island       Entire home/apt              33.28
#                     Private room                 30.16
#                     Shared room                   1.56

# %%
# City by room type reviews
dff.groupby(['neighbourhood','room_type']).agg({'number_of_reviews':'mean'}).round(3) # Multi-Variant Ananlysis
# Out:
#                                number_of_reviews
# neighbourhood room_type
# Allerton      Entire home/apt             54.000
#               Private room                36.115
# Arden Heights Entire home/apt              8.000
#               Private room                 7.000
# Arrochar      Entire home/apt             16.900
# ...                                          ...
# Woodlawn      Shared room                  2.000
# Woodrow       Entire home/apt              0.000
# Woodside      Entire home/apt             42.048
#               Private room                13.906
#               Shared room                  8.000
#
# [540 rows x 1 columns]

# %%
# Price by rooms type reviews
dff.groupby(['room_type','price']).agg({'number_of_reviews':'mean'}).round(2)
# Out:
#                        number_of_reviews
# room_type       price
# Entire home/apt 10                 26.71
#                 11                 56.50
#                 12                  0.00
#                 15                  0.00
#                 16                  8.33
# ...                                  ...
# Shared room     725                 0.00
#                 800                 4.67
#                 1000                0.00
#                 1250                1.00
#                 1800                5.00
#
# [1111 rows x 1 columns]

# %%
# find the number of reviews average
dff['number_of_reviews'].mean()
# Out:
# 23.274465691788528

# %% [markdown]
# * find the number of reviews average is 23.27

# %%
# find the number of reviews maximum
dff['number_of_reviews'].max()
# Out:
# 629

# %% [markdown]
# find the maximum reviews 629

# %%
# find the number of maximum reviews room type
max_room_reviews = dff[dff['number_of_reviews']==629]['room_type']
max_room_reviews.value_counts()
# Out:
# room_type
# Private room    1
# Name: count, dtype: int64

# %% [markdown]
# * find the number of maximum reviews room type
# 1. private room 629 review getting

# %%
# which room type maximun rooms reviews
dff[dff['id']==9145202]
# Out:
#             id                     name   host_id host_name  \
# 11759  9145202  Room near JFK Queen Bed  47621202      Dona
#
#       neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 11759              Queens       Jamaica   40.6673  -73.76831  Private room
#
#        price  minimum_nights  number_of_reviews  \
# 11759     47               1                629
#
#        calculated_host_listings_count  availability_365
# 11759                               2               333

# %% [markdown]
# # Which room type maximum rooms reviews getting
#
# name                           :   Room near JFK Queen Bed
#
# host_id                       :                   47621202
#
# host_name                    :                        Dona
#
# neighbourhood_group         :                       Queens
#
# neighbourhood              :                       Jamaica
#
# latitude                   :                       40.6673
#
# longitude                 :                      -73.76831
#
# room_type                  :                  Private room
#
# price                        :                          47
#
# minimum_nights                 :                         1
#
# number_of_reviews                :                     629
#
# calculated_host_listings_count      :                    2
#
# availability_365                     :                 333

# %%
# find the number of reviews minimum
dff['number_of_reviews'].min()
# Out:
# 0

# %%
# find the number of minimum reviews room type
min_room_reviews = dff[dff['number_of_reviews']==0]['room_type']
min_room_reviews.value_counts()
# Out:
# room_type
# Entire home/apt    5077
# Private room       4661
# Shared room         314
# Name: count, dtype: int64

# %%
# Find the which room type of minimum reviews is 0
minimum_room_reviews = dff[dff['number_of_reviews']==0][['host_id','neighbourhood_group','neighbourhood','room_type']]
minimum_room_reviews
# Out:
#         host_id neighbourhood_group       neighbourhood        room_type
# 2          4632           Manhattan              Harlem     Private room
# 19        17985           Manhattan         East Harlem  Entire home/apt
# 26        26394           Manhattan              Inwood     Private room
# 36         7355            Brooklyn  Bedford-Stuyvesant     Private room
# 38        45445            Brooklyn            Flatbush     Private room
# ...         ...                 ...                 ...              ...
# 48890   8232441            Brooklyn  Bedford-Stuyvesant     Private room
# 48891   6570630            Brooklyn            Bushwick     Private room
# 48892  23492952           Manhattan              Harlem  Entire home/apt
# 48893  30985759           Manhattan      Hell's Kitchen      Shared room
# 48894  68119814           Manhattan      Hell's Kitchen     Private room
#
# [10052 rows x 4 columns]

# %% [markdown]
# # minimum review of zero total number of rooms is 10052
#
# ![image.png](data:image/png;base64,...)

# %%
# Find the review using pivot table
dff.pivot_table(values='availability_365', index='number_of_reviews', columns = 'room_type')
# Out:
# room_type          Entire home/apt  Private room  Shared room
# number_of_reviews
# 0                       114.108529     91.231924   151.229299
# 1                        88.670975     75.248238   163.218978
# 2                        81.396754     81.489322   166.906977
# 3                        85.828762     86.275618   180.410256
# 4                        86.718109     97.357831   169.674419
# ...                            ...           ...          ...
# 576                            NaN    173.000000          NaN
# 594                            NaN    339.000000          NaN
# 597                            NaN    342.000000          NaN
# 607                            NaN    293.000000          NaN
# 629                            NaN    333.000000          NaN
#
# [394 rows x 3 columns]

# %% [markdown]
# # What all manipulations have you done and insights you found?

# %% [markdown]
# * Total number State data city by
#
# *  State              :   City Count
# 2. Manhattan          :    21661
# 3. Brooklyn           :    20104
# 4. Queens             :    5666
# 5. Bronx              :    1091
# 6. Staten Island      :   373
#
# * Total number of city
#
# * City                   : Count
# 1. Williamsburg          : 3920
# 2. Bedford-Stuyvesant    : 3714
# 3. Harlem                : 2658
# 4. Bushwick              : 2465
# 5. Upper West Side       : 1971
#                       ...
# 6. Fort Wadsworth        :   1
# 7. Richmondtown          :   1
# 8. New Dorp              :   1
# 9. Rossville             :  1
# 10. Willowbrook          :   1
#
# * There are 3 type of rooms available
#
# 1. Private room
# 2. Shared room
# 3. Entire home room
#
# * Find the room type Quintity
#
#  * room type         :  count
#
# 1. Entire home/apt   : 25409
# 2. Private room      : 22326
# 3. Shared room       :   1160
#
# * Private room type Price of mean values is 89.78
#
# * Private room type Price of minimun values is 0
#
# * Total  11 rooms Price are 0
#
# 1. Private room price = 0 are 7 rooms
#
# 2. Shared room price = 0 are  2 rooms
#
# 3. Entire home room price = 0 2 rooms
#
# * maximun rooms Price are 10000
#
# 1. There are 3 rooms price are 10k One Private room and Two Entire Home room
#
# *  median room price is 106
#
# * Update room price through median where room price is 0
#
# * After Updated room price no any room price is 0
#
# * which type of room number of review find
#
# 1. Entire home/apt	rooms reviews are 5804031
# 2. Private room	 reviews are 538346
# 3. Shared room	reviews are 19256
#
# * find the room availability in days which type of room available
#
# * find the minimum night stay in private
#
#
#
# * find the minimum night stay in private room
#
# * state by room type reviews
#
# * City by room type reviews
#
# * Price by rooms type reviews
#
# * find the number of reviews average 23
#
# * find the number of reviews maximum  629
#
# *  find the number of maximum reviews room type
#
#    1. Private room
#
# * which room type maximun rooms reviews
#
# *  find the number of reviews minimum 0
#
# * find the number of minimum reviews room type
#
#   1. Entire home/apt    5077
#   2. Private room       4661
#   3. Shared room         314

# %% [markdown]
# # **4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables**

# %% [markdown]
# # Univariant Ananlysis using visualization rooms availability in state relationship

# %%
# chart-1 visualization code
plt.rcParams['figure.figsize'] = (9,9) # increase the Chart size  ( Univariant Analysis)

explode = (0, 0, 0.1, 0, 0) # show the 3d chart

colors = ['#A36E6C','#A3806C','#908652','#B4CD86','#7D7CAC']  # colors difiend

def my_autopct(pct): # Remove overlap in the chart values
    return '{:.1f}%'.format(pct) if pct > 1 else ''

df1.plot(kind='pie', shadow = True, autopct=my_autopct, explode=explode , startangle=140, subplots=True, colors = colors)

#plt.axis('equal')

plt.show()

# %% [markdown]
# * Univariant Ananlysis using visualization rooms availability in state relationship

# %%
# Chart - 2 visualization code
plt.rcParams['figure.figsize'] = (6,6)
plt.scatter(dff['price'], dff['price'], label='price', color='#8499C7')
plt.xlabel('price')
plt.ylabel('price')
plt.title('price Outliers')
_ = plt.legend()

# %% [markdown]
# * find the Outlairs In Price Data using scatter plot visualization.

# %%
# Chart - 3 visualization code
# Categorical-Numerical
plt.figure(figsize=(10, 6))
sns.boxplot(x='room_type', y='price', data=dff, color='#C2A7BC') # Bie-Variant Ananlysis

# Adding titles and labels
plt.title('Price Distribution by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Price')

# Show the plot
plt.show()

# %% [markdown]
# * Find the outlairs in rooms type vs price using box plot visualization.

# %%
# Chart-4 visualization code
sns.heatmap(dff.pivot_table(values='price', index='number_of_reviews', columns = 'room_type'))
# Out:
# <Axes: xlabel='room_type', ylabel='number_of_reviews'>

# %% [markdown]
# * Find the relationship between price , Review and room type using heatmap visualization.

# %%
# Chart-5 visualization code
# Count the data using univariant ananlysis
bar_colors = ['#E7B484','#B17886','#B398C7']

data = dff['room_type'].value_counts()
# Create the bar plot
ax = data.plot(kind='bar', figsize=(5,5), color=bar_colors)

# Add labels to each bar
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

plt.xticks(rotation=45, ha='right')

# Optional: Enhance layout, titles, etc.
ax.set_title('Counts by Room type availablity')
ax.set_xlabel('Rooms Type')
ax.set_ylabel('Counts')

# Show the plot
plt.show()

# %% [markdown]
# * Number of rooms count available of rooms type using bar plot visualization.
# 1. Entire home/apt available is 25409
# 2. private room available is 22326
# 3. shared room available is 1160

# %%
# Chart-6 visualization code
plt.rcParams['figure.figsize'] = (8,6) # increase the Chart size  ( Univariant Analysis)

explode = (0, 0, 0.2) # show the 3d chart

colors = ['#E7B484','#B17886','#B398C7']  # colors difiend

def my_autopct(pct): # Remove overlap in the chart values
    return '{:.1f}%'.format(pct) if pct > 1 else ''

dff['room_type'].value_counts().plot(kind='pie', shadow = True, autopct=my_autopct, explode=explode , startangle=120, subplots=True, colors = colors)

#plt.axis('equal')
_ = plt.legend()
plt.show()

# %% [markdown]
# * Number of rooms in % available of rooms type using Pie Chart visualization.
# 1. Entire home/apt available is 52%
# 2. private room available is 45%
# 3. shared room available is 2.4%

# %%
# Chart-7 visualization code
#Univariant Ananlysis
data = dff['neighbourhood_group'].value_counts()

bar_colors = ['#E89898','#CDAB94','#CEC09E','#C8CE9E','#B1C2A7']

# Create the bar plot
ax = data.plot(kind='bar', color=bar_colors)

# Add labels to each bar
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# set rotation
plt.xticks(rotation=45, ha='left')

# Optional: Enhance layout, titles, etc.
ax.set_title('Counts by State wise City')
ax.set_xlabel('Neighbourhood Group')
ax.set_ylabel('Counts')

# Show the plot
plt.show()

# %% [markdown]
# * State counts in rooms available using bar plot visualization.
# 1. manhattan = 21661
# 2. Brooklyn = 20104
# 3. Queens = 5666
# 5. Bronx = 1091
# 6. Staten Island = 373

# %%
# Chart-8 visualization code
# Numerical-Numerical

min_room_reviews = dff[dff['number_of_reviews']==0]['room_type']

max_room_reviews = dff[dff['number_of_reviews']==629]['room_type']

price_room_min = dff.groupby('room_type')['price'].min()

price_room_max = dff.groupby('room_type')['price'].max()

avg_room_reviews = dff.groupby('room_type')['number_of_reviews'].mean()


room = dff['room_type'].value_counts()
mi_rr = min_room_reviews.value_counts()
max_rr = max_room_reviews.value_counts()


# Fixed the plot size
plt.rcParams['figure.figsize'] = (9,6)

# Plot the line

plt.plot(price_room_min, label= 'price_room_min', marker='o', markerfacecolor='#A36B78', color='#A36B78')
plt.plot(price_room_max, label= 'price_room_max', marker='o', markerfacecolor='#D0A0C6', color='#D0A0C6')
plt.plot(mi_rr, label= 'Minimun_number_of_reviews', marker='o', markerfacecolor='#7780A5', color ='#7780A5')
plt.plot(max_rr, label= 'Max_number_of_reviews', marker='o', markerfacecolor='#859E84', color='#859E84')


# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding labels and title
plt.xlabel('Room_type')
plt.ylabel('Price')
plt.title('Room Type Reviews  & Room Type Price Minimum and maximum')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# * Find the ralationship between minimum reviews , Maximum review, minimum price, maximum price with room type Visualization Line chart

# %%
# Chart-9 visualization code
# Multi-variant Analysis
sns.scatterplot(x='price', y='number_of_reviews', data=dff, hue='room_type', style='neighbourhood_group', size='price', sizes=(10, 100))
plt.title('Scatter Plot of Number of Reviews vs Price')
plt.xlabel('Price')
plt.ylabel('Number of Reviews')
plt.show()

# %% [markdown]
# * Find the ralationship between reviews , state, price, with room type Visualization scatter plot
#
# 1. Around 0 - 2000 price of rooms type ( Entaire and Private room ) in state ( Manhattan and Brooklyn and Queens ) very hign demand area.

# %%
# Chart-10 visualization code
# According to find room_type vs price
# Categorical-Numerical
bar_colors = ['#E89898','#CDAB94','#CEC09E','#C8CE9E','#B1C2A7']
sns.barplot(x='room_type', y='price', data=dff, hue='neighbourhood_group', palette=bar_colors) # Bie-Variant analysis


# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding titles and labels
plt.title('Price by Room Type and State wise')
plt.xlabel('Room Type')
plt.ylabel('Price')

# Show the plot
plt.show()

# %% [markdown]
# * According to find room_type vs price relationship using barplot visualizations.

# %%
# Chart-11 visualization code
# Find the outlayer using room type vs price
# Categorical-Numerical
plt.figure(figsize=(10, 6))
sns.boxplot(x='room_type', y='price', data=dff, color='#C2A7BC') # Bie-Variant Ananlysis

# Adding titles and labels
plt.title('Price Distribution by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Price')

# Show the plot
plt.show()

# %% [markdown]
# * Find the outlairs in rooms type vs price using box plot visualization.

# %%
# Chart-12 visualization code
# Categorical-Categorical
sns.clustermap(pd.crosstab(dff['room_type'], dff['neighbourhood_group'])) # Bie-Variant Analysis

# %% [markdown]
# * Bie-Variant Ananlysis using cluster map relationship between state and room type

# %%
# Chart-13 visualization code
# Grouping the data and aggregating
grouped_data = dff.groupby(['neighbourhood_group','room_type']).agg({'number_of_reviews':'mean'}).round(2)

# Sorting the grouped data in ascending order
grouped_data_sorted = grouped_data.sort_values(by='number_of_reviews', ascending=False)


#set the color
bar_colors = ['#869C71']


# Creating the bar plot
ax = grouped_data_sorted.plot(kind='bar', figsize=(10, 6), color=bar_colors)

# Add labels to each bar
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# Adding titles and labels
plt.title('Sum of Number of Reviews by Neighbourhood Group and Room Type')
plt.xlabel('Neighbourhood Group, Room Type')
plt.ylabel('Sum of Number of Reviews')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding legend
plt.legend(title='Room Type', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %% [markdown]
# * Multi-Variant Ananlysis using barplot relationship between state and room type and number Review According Room type and which state.

# %% [markdown]
# # **Chart - 14 - Correlation Heatmap**

# %% [markdown]
# 1. Why did you pick the specific chart?
#
# * Find the all Numerical data relationship using corelation.

# %%
# Find the Correlation
object_columns = dff.select_dtypes(include=['object']).columns
df_numeric = dff.drop(columns=object_columns)
df_numeric.corr()
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.588290 -0.003125   0.090908
# host_id                         0.588290  1.000000  0.020224   0.127055
# latitude                       -0.003125  0.020224  1.000000   0.084788
# longitude                       0.090908  0.127055  0.084788   1.000000
# price                           0.010633  0.015298  0.033909  -0.149968
# minimum_nights                 -0.013224 -0.017364  0.024869  -0.062747
# number_of_reviews              -0.319760 -0.140106 -0.015389   0.059094
# calculated_host_listings_count  0.133272  0.154950  0.019517  -0.114713
# availability_365                0.085468  0.203492 -0.010983   0.082731
#
#                                    price  minimum_nights  number_of_reviews  \
# id                              0.010633       -0.013224          -0.319760
# host_id                         0.015298       -0.017364          -0.140106
# ...

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(9, 6))

dataplot = sns.heatmap(df_numeric.corr(), cmap="YlGnBu", annot=True) # Multivariant analysis

plt.xticks(rotation=45, ha='right')

plt.yticks(rotation=45, ha='right')

# displaying heatmap
plt.show()

# %% [markdown]
# # **Chart - 15 - Pair Plot**

# %%
# Pairplot
desired_columns = ['neighbourhood_group', 'neighbourhood', 'room_type', 'price', 'number_of_reviews','calculated_host_listings_count','availability_365']
subset_dff = dff[desired_columns]
sns.pairplot(subset_dff, hue='neighbourhood_group', diag_kind="kde", palette='viridis', height=2.5)
plt.show()

# %% [markdown]
# # **5. Solution to Business Objective**

# %% [markdown]
# # What do you suggest the client to achieve Business Objective ?
#
# To achieve the business objectives outlined in the problem statement for optimizing Airbnb listings in New York City, I would suggest the following strategies:
#
# 1. **Data-Driven Pricing Strategy:** Implement a data-driven pricing strategy based on the analysis of factors influencing listing prices, such as property attributes, location, seasonality, and host characteristics. Utilize pricing optimization tools or algorithms to dynamically adjust prices in response to market demand, competitor pricing, and seasonal trends.
#
# 2. **Listing Optimization**: Enhance the quality and appeal of Airbnb listings by optimizing property descriptions, photos, and amenities based on insights derived from the analysis. Emphasize unique selling points and highlight features that resonate with target guest demographics to attract more bookings and command higher prices.
#
# 3. ** Guest Experience Enhancement**: Prioritize guest satisfaction by focusing on factors that drive positive reviews and repeat bookings. Implement guest-centric initiatives such as personalized welcome messages, responsive communication, and thoughtful amenities to enhance the overall guest experience and cultivate loyalty.
#
# 4. **Regulatory Compliance**: Stay abreast of regulatory requirements governing short-term rentals in New York City and ensure compliance with local laws and regulations. Partner with legal experts or consult industry associations to navigate regulatory complexities and mitigate risks associated with non-compliance.
#
# 5. **Continuous Monitoring and Optimization**: Establish a framework for continuous monitoring and optimization of Airbnb listings, pricing strategies, and guest satisfaction metrics. Leverage analytics dashboards and performance metrics to track key performance indicators (KPIs) and identify opportunities for improvement.
#
# 6. **Market Differentiation:** Differentiate Airbnb listings by offering unique experiences, personalized touches, and exceptional service that set them apart from competitors. Identify niche markets or target segments and tailor offerings to meet their specific needs and preferences.
#
# 7. **Investment in Technology:** Invest in technology solutions such as channel managers, property management systems (PMS), and data analytics tools to streamline operations, automate tasks, and gain actionable insights from data. Leverage emerging technologies such as artificial intelligence (AI) and machine learning (ML) to optimize pricing, predict demand, and personalize guest experiences.
#
# 8. **Collaboration and Partnerships:** Explore collaboration opportunities with local businesses, tourism organizations, and hospitality industry partners to cross-promote listings, access new markets, and enhance guest experiences through partnerships and joint initiatives.
#
#
# By implementing these strategies, the client can effectively achieve their business objectives of maximizing revenue, enhancing guest satisfaction, ensuring regulatory compliance, and optimizing the performance of Airbnb listings in New York City. These initiatives will position the client for success in the competitive Airbnb market while delivering exceptional value to both hosts and guests.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, the "Airbnb NYC 2019 Data Analysis" project presents a comprehensive exploration of the New York City Airbnb market, aimed at empowering hosts and guests with actionable insights to optimize listing performance, enhance guest experiences, and navigate regulatory complexities.
#
# Through meticulous data analysis and strategic recommendations, the project has shed light on the multifaceted dynamics of the Airbnb ecosystem, uncovering key factors influencing pricing dynamics, occupancy rates, and guest satisfaction metrics. By leveraging data-driven pricing strategies, enhancing listing quality, and prioritizing guest-centric initiatives, hosts can maximize revenue opportunities while cultivating positive reputations and fostering guest loyalty.
#
# Furthermore, the project underscores the importance of regulatory compliance in the short-term rental landscape, urging hosts to stay informed of local laws and regulations to mitigate risks and ensure ethical and responsible operations.
#
# As the hospitality industry continues to evolve, the insights gleaned from this analysis serve as a compass for navigating the complexities of the Airbnb marketplace, driving innovation, and fostering sustainable growth. By embracing data-driven decision-making, technological advancements, and collaborative partnerships, stakeholders can unlock the full potential of Airbnb listings in New York City, creating memorable experiences for guests and driving economic prosperity for hosts and communities alike.
#
# In essence, the "Airbnb NYC 2019 Data Analysis" project embodies a commitment to excellence, integrity, and innovation, laying the groundwork for a vibrant and thriving Airbnb ecosystem that enriches lives, fosters connections, and transforms the way we experience hospitality in the heart of the Big Apple.
